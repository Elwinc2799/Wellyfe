# %% [markdown]
# <center>
#
# #     Big Five Personality Test

# %% [markdown]
# <center>
# <img src='https://blog.adioma.com/wp-content/uploads/2018/11/big-five-personality-traits-infographic.png' width='500'>

# %% [markdown]
# * 1. What is the Big Five personality test used for?
# * 2. Big Five personality traits
#
#     * 2.1. Q&As Related to Extroversion Personality
#     * 2.2. Q&As Related to Neuroticism Personality
#     * 2.3. Q&As Related to Agreeable Personality
#     * 2.4. Q&As Related to Conscientious Personality
#     * 2.5. Q&As Related to Open Personality
#
#
# * 3. The Big Five Personality Test in across Countries
#
#     * 3.1. Extroversion Personality
#     * 3.2. Neuroticism Personality
#     * 3.3. Agreeable Personality
#     * 3.4. Conscientious Personality
#     * 3.5. Related to Open Personality
#
#
# * 4. Clustering
#     * 4.1 K-means
#     * 4.2 PCA
#     * 4.3 TSNE

# %% [markdown]
# # 1. What is the Big Five personality test used for?
#
#
# The Big Five personality test gives you more insight into how you react in different situations, which can help you choose an occupation. Career professionals and psychologists use this information in a personality career test for recruitment and candidate assessment[[1]( https://www.123test.com/big-five-personality-theory/)].
#
#
# The big five come from the statistical study of responses to personality items. Using a technique called factor analysis researchers can look at the responses of people to hundreds of personality items and ask the question "what is the best was to summarize an individual?". This has been done with many samples from all over the world and the general result is that, while there seem to be unlimited personality variables, five stand out from the pack in terms of explaining a lot of a persons answers to questions about their personality: extraversion, neuroticism, agreeableness, conscientiousness and openness to experience. The big-five are not associated with any particular test, a variety of measures have been developed to measure them. This test uses the Big-Five Factor Markers from the International Personality Item Pool, developed by Goldberg (1992)[[2](https://openpsychometrics.org/tests/IPIP-BFFM/)].
#
# * Procedure
#
# The test consists of fifty items that you must rate on how true they are about you on a five point scale where 1=Disagree, 3=Neutral and 5=Agree. It takes most people 3-8 minutes to complete.

# %%
import numpy as np
import pylab as pl
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import wordcloud
from wordcloud import WordCloud,STOPWORDS
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.utils import shuffle
import matplotlib.ticker as mtick

# Plotly
import plotly.express as px
import plotly.graph_objects as go
import colorlover as cl
from plotly.subplots import make_subplots

# %%
data = pd.read_csv('../input/big-five-personality-test/IPIP-FFM-data-8Nov2018/data-final.csv', delimiter='\t')
data
# Out:
#          EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0         4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1         3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2         2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3         2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4         3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 1015336   4.0   2.0   4.0   3.0   4.0   3.0   3.0   3.0   3.0    3.0  ...
# 1015337   4.0   3.0   4.0   3.0   3.0   3.0   4.0   4.0   3.0    3.0  ...
# 1015338   4.0   2.0   4.0   3.0   5.0   1.0   4.0   2.0   4.0    4.0  ...
# 1015339   2.0   4.0   3.0   4.0   2.0   2.0   1.0   4.0   2.0    4.0  ...
# 1015340   4.0   2.0   4.0   2.0   4.0   1.0   4.0   2.0   4.0    4.0  ...
#
#                     dateload  screenw  screenh  introelapse  testelapse  \
# 0        2016-03-03 02:01:01    768.0   1024.0          9.0       234.0
# 1        2016-03-03 02:01:20   1360.0    768.0         12.0       179.0
# 2        2016-03-03 02:01:56   1366.0    768.0          3.0       186.0
# 3        2016-03-03 02:02:02   1920.0   1200.0        186.0       219.0
# 4        2016-03-03 02:02:57   1366.0    768.0          8.0       315.0
# ...                      ...      ...      ...          ...         ...
# 1015336  2018-11-08 12:04:58   1920.0   1080.0          3.0       160.0
# 1015337  2018-11-08 12:07:18   1920.0   1080.0          3.0       122.0
# 1015338  2018-11-08 12:07:49   1920.0   1080.0          2.0       135.0
# 1015339  2018-11-08 12:08:34   1920.0   1080.0          6.0       212.0
# 1015340  2018-11-08 12:08:45   1920.0   1080.0          3.0       176.0
#
#          endelapse  IPC  country  lat_appx_lots_of_err  long_appx_lots_of_err
# 0                6    1       GB               51.5448                 0.1991
# 1               11    1       MY                3.1698                101.706
# 2                7    1       GB               54.9119                -1.3833
# 3                7    1       GB                 51.75                  -1.25
# 4               17    2       KE                   1.0                   38.0
# ...            ...  ...      ...                   ...                    ...
# 1015336         10    2       US               39.9883               -75.2208
# 1015337          7    1       US                  38.0                  -97.0
# 1015338         12    6       US               36.1473                -86.777
# 1015339          8    1       US               34.1067              -117.8067
# 1015340          9    1       US                  38.0                  -97.0
#
# [1015341 rows x 110 columns]

# %%
#Check Missing Value
print('Is there any missing value? ', data.isnull().values.any())
print('How many missing values? ', data.isnull().values.sum())
data.dropna(inplace=True)
print('Number of participants after eliminating missing values: ', len(data))
# Out:
# Is there any missing value?  True
# How many missing values?  186358
# Number of participants after eliminating missing values:  1012050

# %% [markdown]
# # 2. Big Five personality traits
#
# The Big Five personality traits are:
#
# * Openness :
#
# People who like to learn new things and enjoy new experiences usually score high in openness. Openness includes traits like being insightful and imaginative and having a wide variety of interests.
#
# * Conscientiousness :
#
# People that have a high degree of conscientiousness are reliable and prompt. Traits include being organized, methodic, and thorough.
#
# * Extraversion :
#
# Extraverts get their energy from interacting with others, while introverts get their energy from within themselves. Extraversion includes the traits of energetic, talkative, and assertive.
#
# * Agreeableness :
#
# These individuals are friendly, cooperative, and compassionate. People with low agreeableness may be more distant. Traits include being kind, affectionate, and sympathetic.
#
# * Neuroticism :
#
# Neuroticism is also sometimes called Emotional Stability. This dimension relates to one’s emotional stability and degree of negative emotions. People that score high on neuroticism often experience emotional instability and negative emotions. Traits include being moody and tense.

# %% [markdown]
# ## 2.1. Q&As Related to Extroversion Personality
#
#   * EXT1 : I am the life of the party,
#   * EXT2 : I dont talk a lot,
#   * EXT3 : I feel comfortable around people,
#   * EXT4 : I keep in the background,
#   * EXT5 : I start conversations,
#   * EXT6 : I have little to say,
#   * EXT7 : I talk to a lot of different people at parties,
#   * EXT8 : I dont like to draw attention to myself,
#   * EXT9 : I dont mind being the center of attention,
#   * EXT10: I am quiet around strangers

# %%
#barplots showing the frequency of each category
plt.figure(figsize=[15,15])
fft=['EXT1','EXT2','EXT3','EXT4','EXT5','EXT6','EXT7','EXT8','EXT9','EXT10']
n=1
for f in fft:
    plt.subplot(5,2,n)
    sns.countplot(x=f,  edgecolor="black", alpha=0.7, data=data)
    sns.despine()
    plt.title("Q&As Related to Extroversion Personality : {} ".format(f))
    n=n+1
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.2. Q&As Related to Neuroticism Personality
#
# * EST1 : I get stressed out easily,
# * EST2 : I am relaxed most of the time,
# * EST3 : I worry about things,
# * EST4 : I seldom feel blue,
# * EST5 : I am easily disturbed,
# * EST6 : I get upset easily,
# * EST7 : I change my mood a lot,
# * EST8 : I have frequent mood swings,
# * EST9 : I get irritated easily,
# * EST10: I often feel blue

# %%
#barplots showing the frequency of each category 
plt.figure(figsize=[15,15])
fft=['EST1','EST2','EST3','EST4','EST5','EST6','EST7','EST8','EST9','EST10']
n=1
for f in fft:
    plt.subplot(5,2,n)
    sns.countplot(x=f,  edgecolor="black", alpha=0.7, data=data)
    sns.despine()
    plt.title("Q&As Related to Neuroticism Personality : {} ".format(f))
    n=n+1
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.3. Q&As Related to Agreeable Personality
#
# * AGR1 : I feel little concern for others,
# * AGR2 : I am interested in people,
# * AGR3 : I insult people,
# * AGR4 : I sympathize with others feelings,
# * AGR5 : I am not interested in other peoples problems,
# * AGR6 : I have a soft heart,
# * AGR7 : I am not really interested in others,
# * AGR8 : I take time out for others,
# * AGR9 : I feel others emotions,
# * AGR10: I make people feel at ease

# %%
#barplots showing the frequency of each category 
plt.figure(figsize=[15,15])
fft=['AGR1','AGR2','AGR3','AGR4','AGR5','AGR6','AGR7','AGR8','AGR9','AGR10']
n=1
for f in fft:
    plt.subplot(5,2,n)
    sns.countplot(x=f, edgecolor="black", alpha=0.7, data=data)
    sns.despine()
    plt.title("Q&As Related to Agreeable Personality : {} ".format(f))
    n=n+1
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.4. Q&As Related to Conscientious Personality
#
# * CSN1 : I am always prepared,
# * CSN2 : I leave my belongings around,
# * CSN3 : I pay attention to details,
# * CSN4 : I make a mess of things,
# * CSN5 : I get chores done right away,
# * CSN6 : I often forget to put things back in their proper place,
# * CSN7 : I like order,
# * CSN8 : I shirk my duties,
# * CSN9 : I follow a schedule,
# * CSN10 : I am exacting in my work

# %%
#barplots showing the frequency of each category 
plt.figure(figsize=[15,15])
fft=['CSN1','CSN2','CSN3','CSN4','CSN5','CSN6','CSN7','CSN8','CSN9','CSN10']
n=1
for f in fft:
    plt.subplot(5,2,n)
    sns.countplot(x=f, edgecolor="black", alpha=0.7, data=data)
    sns.despine()
    plt.title("Q&As Related to Conscientious Personality: {} ".format(f))
    n=n+1
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.5. Q&As Related to Open Personality
#
#
# * OPN1 : I have a rich vocabulary,
# * OPN2 : I have difficulty understanding abstract ideas,
# * OPN3 : I have a vivid imagination,
# * OPN4 : I am not interested in abstract ideas,
# * OPN5 : I have excellent ideas,
# * OPN6 : I do not have a good imagination,
# * OPN7 : I am quick to understand things,
# * OPN8 : I use difficult words,
# * OPN9 : I spend time reflecting on things,
# * OPN10: I am full of ideas

# %%
#barplots showing the frequency of each category 
plt.figure(figsize=[15,15])
fft=['OPN1','OPN2','OPN3','OPN4','OPN5','OPN6','OPN7','OPN8','OPN9','OPN10']
n=1
for f in fft:
    plt.subplot(5,2,n)
    sns.countplot(x=f,  edgecolor="black", alpha=0.7, data=data)
    sns.despine()
    plt.title("Q&As Related to Open Personality : {}  ".format(f))
    n=n+1
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. The Big Five Personality Test in across Countries (by Continent)

# %%
continents= pd.read_csv('../input/country-mapping-iso-continent-region/continents2.csv')
continents
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
#              sub-region intermediate-region  region-code  sub-region-code  \
# 0         Southern Asia                 NaN        142.0             34.0
# 1       Northern Europe                 NaN        150.0            154.0
# 2       Southern Europe                 NaN        150.0             39.0
# 3       Northern Africa                 NaN          2.0             15.0
# 4             Polynesia                 NaN          9.0             61.0
# ..                  ...                 ...          ...              ...
# 244           Polynesia                 NaN          9.0             61.0
# 245     Northern Africa                 NaN          2.0             15.0
# 246        Western Asia                 NaN        142.0            145.0
# 247  Sub-Saharan Africa      Eastern Africa          2.0            202.0
# 248  Sub-Saharan Africa      Eastern Africa          2.0            202.0
#
#      intermediate-region-code
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 244                       NaN
# 245                       NaN
# 246                       NaN
# 247                      14.0
# 248                      14.0
#
# [249 rows x 11 columns]

# %%
data1=data.copy()
data1['alpha-2']=data1['country']

# %%
continents = data1.merge(continents, on=["alpha-2"], how='left')

# %% [markdown]
# ## 3.1. Extroversion Personality

# %%
#Viz Ref: https://www.kaggle.com/dwin183287/kagglers-seen-by-continents
EP_lst = ['EXT1','EXT2','EXT3','EXT4','EXT5','EXT6','EXT7','EXT8','EXT9','EXT10'] 
EP_df = continents.groupby(["region"])[EP_lst].count()
EP_df.columns = ['I am the life of the party','I dont talk a lot','I feel comfortable around people',
                'I keep in the background','I start conversations','I have little to say',
                'I talk to a lot of different people at parties','I dont like to draw attention to myself',
                'I dont mind being the center of attention','I am quiet around strangers']
EP_df = EP_df.loc[['Africa','Americas','Asia','Europe','Oceania'], :]
EP_df = EP_df.T

EP_df["World"] = EP_df.sum(axis=1)
EP_df = EP_df.sort_values(by="World", ascending=True)
EP_df["Min"] = EP_df.min(axis=1)
EP_df["Max"] = EP_df.max(axis=1)

# %%
# Setting up figure and axes
fig = plt.figure(figsize=(10,5)) # create figure
gs = fig.add_gridspec(1, 1)
gs.update(wspace=0, hspace=0)
ax0 = fig.add_subplot(gs[0, 0])

# Change background color
background_color = "#fbfbfb"
fig.patch.set_facecolor(background_color) # figure background color
ax0.set_facecolor(background_color) # axes background color

y_dummy = np.arange(1,len(EP_df.index)+1)

ax0.hlines(y=y_dummy, xmin=EP_df["Min"], xmax=EP_df["Max"], color='grey', alpha=0.4, zorder=3)
ax0.scatter(EP_df['World'], y_dummy, color='red', label='World')
ax0.scatter(EP_df['Africa'], y_dummy, color='green', label='Africa')
ax0.scatter(EP_df['Americas'], y_dummy, color='blue', label='Americas')
ax0.scatter(EP_df['Asia'], y_dummy, color='orange', label='Asia')
ax0.scatter(EP_df['Europe'], y_dummy, color='skyblue', label='Europe')
ax0.scatter(EP_df['Oceania'], y_dummy, color='magenta', label='Oceania')

y_label = list(EP_df.index)
y_label.insert(0, "")
ax0.yaxis.set_major_locator(mtick.MultipleLocator(1))
ax0.set_yticklabels(y_label)
ax0.set_xticklabels([])
ax0.tick_params(bottom=False)
   
ax0.text(-100, 14, 
         'Visualization Extraversion Personality traits across Countries (by Continent)', 
         fontsize=20, fontweight='bold', fontfamily='serif') 



ax0.legend(loc='lower center', ncol=7, bbox_to_anchor=(0.53, -0.1))

for s in ["top","right", "left", "bottom"]:
    ax0.spines[s].set_visible(False)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
display(continents[['EXT1','EXT2','EXT3','EXT4','EXT5','EXT6','EXT7','EXT8','EXT9','EXT10','region']].groupby(['region']).agg(["min","max",'mean','sum']).style.background_gradient(cmap="GnBu"))
# Out:
# <style  type="text/css" >
# #T_efc29_row0_col0,#T_efc29_row0_col1,#T_efc29_row0_col2,#T_efc29_row0_col3,#T_efc29_row0_col4,#T_efc29_row0_col5,#T_efc29_row0_col7,#T_efc29_row0_col8,#T_efc29_row0_col9,#T_efc29_row0_col11,#T_efc29_row0_col12,#T_efc29_row0_col13,#T_efc29_row0_col15,#T_efc29_row0_col16,#T_efc29_row0_col17,#T_efc29_row0_col18,#T_efc29_row0_col19,#T_efc29_row0_col20,#T_efc29_row0_col21,#T_efc29_row0_col23,#T_efc29_row0_col24,#T_efc29_row0_col25,#T_efc29_row0_col26,#T_efc29_row0_col27,#T_efc29_row0_col28,#T_efc29_row0_col29,#T_efc29_row0_col31,#T_efc29_row0_col32,#T_efc29_row0_col33,#T_efc29_row0_col34,#T_efc29_row0_col35,#T_efc29_row0_col36,#T_efc29_row0_col37,#T_efc29_row0_col39,#T_efc29_row1_col0,#T_efc29_row1_col1,#T_efc29_row1_col4,#T_efc29_row1_col5,#T_efc29_row1_col8,#T_efc29_row1_col9,#T_efc29_row1_col12,#T_efc29_row1_col13,#T_efc29_row1_col16,#T_efc29_row1_col17,#T_efc29_row1_col20,#T_efc29_row1_col21,#T_efc29_row1_col24,#T_efc29_row1_col25,#T_efc29_row1_col28,#T_efc29_row1_col29,#T_efc29_row1_col32,#T_efc29_row1_col33,#T_efc29_row1_col36,#T_efc29_row1_col37,#T_efc29_row2_col0,#T_efc29_row2_col1,#T_efc29_row2_col4,#T_efc29_row2_col5,#T_efc29_row2_col8,#T_efc29_row2_col9,#T_efc29_row2_col12,#T_efc29_row2_col13,#T_efc29_row2_col16,#T_efc29_row2_col17,#T_efc29_row2_col20,#T_efc29_row2_col21,#T_efc29_row2_col24,#T_efc29_row2_col25,#T_efc29_row2_col28,#T_efc29_row2_col29,#T_efc29_row2_col30,#T_efc29_row2_col32,#T_efc29_row2_col33,#T_efc29_row2_col36,#T_efc29_row2_col37,#T_efc29_row3_col0,#T_efc29_row3_col1,#T_efc29_row3_col4,#T_efc29_row3_col5,#T_efc29_row3_col8,#T_efc29_row3_col9,#T_efc29_row3_col10,#T_efc29_row3_col12,#T_efc29_row3_col13,#T_efc29_row3_col16,#T_efc29_row3_col17,#T_efc29_row3_col20,#T_efc29_row3_col21,#T_efc29_row3_col22,#T_efc29_row3_col24,#T_efc29_row3_col25,#T_efc29_row3_col28,#T_efc29_row3_col29,#T_efc29_row3_col32,#T_efc29_row3_col33,#T_efc29_row3_col36,#T_efc29_row3_col37,#T_efc29_row3_col38,#T_efc29_row4_col0,#T_efc29_row4_col1,#T_efc29_row4_col4,#T_efc29_row4_col5,#T_efc29_row4_col6,#T_efc29_row4_col8,#T_efc29_row4_col9,#T_efc29_row4_col12,#T_efc29_row4_col13,#T_efc29_row4_col14,#T_efc29_row4_col16,#T_efc29_row4_col17,#T_efc29_row4_col20,#T_efc29_row4_col21,#T_efc29_row4_col24,#T_efc29_row4_col25,#T_efc29_row4_col28,#T_efc29_row4_col29,#T_efc29_row4_col32,#T_efc29_row4_col33,#T_efc29_row4_col36,#T_efc29_row4_col37{
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }#T_efc29_row0_col6,#T_efc29_row0_col30,#T_efc29_row0_col38,#T_efc29_row1_col3,#T_efc29_row1_col7,#T_efc29_row1_col11,#T_efc29_row1_col15,#T_efc29_row1_col19,#T_efc29_row1_col23,#T_efc29_row1_col27,#T_efc29_row1_col31,#T_efc29_row1_col35,#T_efc29_row1_col39,#T_efc29_row2_col14,#T_efc29_row2_col22,#T_efc29_row2_col34,#T_efc29_row4_col2,#T_efc29_row4_col10,#T_efc29_row4_col18,#T_efc29_row4_col26{
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_efc29_row0_col10{
#             background-color:  #ceecc7;
#             color:  #000000;
#         }#T_efc29_row0_col14,#T_efc29_row1_col10{
#             background-color:  #2889bc;
#             color:  #000000;
#         }#T_efc29_row0_col22{
#             background-color:  #80cec2;
#             color:  #000000;
#         }#T_efc29_row1_col2{
#             background-color:  #0861a4;
#             color:  #f1f1f1;
#         }#T_efc29_row1_col6{
#             background-color:  #d6efd0;
#             color:  #000000;
#         }#T_efc29_row1_col14,#T_efc29_row3_col15,#T_efc29_row3_col35{
#             background-color:  #c4e8c1;
#             color:  #000000;
#         }#T_efc29_row1_col18{
#             background-color:  #68c1ca;
#             color:  #000000;
#         }#T_efc29_row1_col22{
#             background-color:  #f2faeb;
#             color:  #000000;
#         }#T_efc29_row1_col26{
#             background-color:  #41a5cb;
#             color:  #000000;
#         }#T_efc29_row1_col30{
#             background-color:  #084384;
#             color:  #f1f1f1;
#         }#T_efc29_row1_col34{
#             background-color:  #65c0cb;
#             color:  #000000;
#         }#T_efc29_row1_col38{
#             background-color:  #46aace;
#             color:  #000000;
#         }#T_efc29_row2_col2{
#             background-color:  #4aafd1;
#             color:  #000000;
#         }#T_efc29_row2_col3,#T_efc29_row2_col11,#T_efc29_row2_col18,#T_efc29_row2_col19{
#             background-color:  #dff2da;
#             color:  #000000;
#         }#T_efc29_row2_col6{
#             background-color:  #3699c5;
#             color:  #000000;
#         }#T_efc29_row2_col7,#T_efc29_row2_col35{
#             background-color:  #ddf2d8;
#             color:  #000000;
#         }#T_efc29_row2_col10{
#             background-color:  #c2e7c0;
#             color:  #000000;
#         }#T_efc29_row2_col15,#T_efc29_row2_col39{
#             background-color:  #def2d9;
#             color:  #000000;
#         }#T_efc29_row2_col23{
#             background-color:  #dbf1d5;
#             color:  #000000;
#         }#T_efc29_row2_col26{
#             background-color:  #f0f9e9;
#             color:  #000000;
#         }#T_efc29_row2_col27{
#             background-color:  #dff3da;
#             color:  #000000;
#         }#T_efc29_row2_col31{
#             background-color:  #e0f3db;
#             color:  #000000;
#         }#T_efc29_row2_col38{
#             background-color:  #084182;
#             color:  #f1f1f1;
#         }#T_efc29_row3_col2{
#             background-color:  #7dcdc3;
#             color:  #000000;
#         }#T_efc29_row3_col3,#T_efc29_row3_col31{
#             background-color:  #c6e9c2;
#             color:  #000000;
#         }#T_efc29_row3_col6{
#             background-color:  #97d6bb;
#             color:  #000000;
#         }#T_efc29_row3_col7{
#             background-color:  #c3e7c1;
#             color:  #000000;
#         }#T_efc29_row3_col11{
#             background-color:  #c7e9c3;
#             color:  #000000;
#         }#T_efc29_row3_col14{
#             background-color:  #bde5be;
#             color:  #000000;
#         }#T_efc29_row3_col18{
#             background-color:  #ddf2d7;
#             color:  #000000;
#         }#T_efc29_row3_col19,#T_efc29_row3_col23,#T_efc29_row3_col27,#T_efc29_row3_col39{
#             background-color:  #c5e8c2;
#             color:  #000000;
#         }#T_efc29_row3_col26{
#             background-color:  #84cfc1;
#             color:  #000000;
#         }#T_efc29_row3_col30{
#             background-color:  #64bfcc;
#             color:  #000000;
#         }#T_efc29_row3_col34{
#             background-color:  #50b4d2;
#             color:  #000000;
#         }#T_efc29_row4_col3,#T_efc29_row4_col11,#T_efc29_row4_col15,#T_efc29_row4_col23,#T_efc29_row4_col31,#T_efc29_row4_col35,#T_efc29_row4_col39{
#             background-color:  #e8f6e2;
#             color:  #000000;
#         }#T_efc29_row4_col7{
#             background-color:  #e9f6e3;
#             color:  #000000;
#         }#T_efc29_row4_col19,#T_efc29_row4_col27{
#             background-color:  #e7f6e2;
#             color:  #000000;
#         }#T_efc29_row4_col22{
#             background-color:  #e1f4dc;
#             color:  #000000;
#         }#T_efc29_row4_col30{
#             background-color:  #1c7cb6;
#             color:  #000000;
#         }#T_efc29_row4_col34{
#             background-color:  #7accc4;
#             color:  #000000;
#         }#T_efc29_row4_col38{
#             background-color:  #d1edcb;
#             color:  #000000;
#         }</style><table id="T_efc29_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="4">EXT1</th>        <th class="col_heading level0 col4" colspan="4">EXT2</th>        <th class="col_heading level0 col8" colspan="4">EXT3</th>        <th class="col_heading level0 col12" colspan="4">EXT4</th>        <th class="col_heading level0 col16" colspan="4">EXT5</th>        <th class="col_heading level0 col20" colspan="4">EXT6</th>        <th class="col_heading level0 col24" colspan="4">EXT7</th>        <th class="col_heading level0 col28" colspan="4">EXT8</th>        <th class=

# %%
continents[['EXT1','EXT2','EXT3','EXT4','EXT5','EXT6','EXT7','EXT8','EXT9','EXT10','dateload','region']].groupby(['region']).agg(["sum"]).plot(kind="line",color =["orange","blue","green",'red','magenta','pink','skyblue','yellow','purple','black'])
plt.title("Sum : Extroversion Personality traits across Countries (by Continent)", fontsize=20)
plt.ylabel("Extroversion Personality",fontsize=10)
plt.xlabel(" ")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 3.2. Neuroticism Personality

# %%
NP_lst = ['EST1','EST2','EST3','EST4','EST5','EST6','EST7','EST8','EST9','EST10'] 
NP_df = continents.groupby(["region"])[NP_lst].count()
NP_df.columns = ['I get stressed out easily', 'I am relaxed most of the time','I worry about things',
                'I seldom feel blue','I am easily disturbed','I get upset easily','I change my mood a lot',
                'I have frequent mood swings','I get irritated easily','I often feel blue']
NP_df = NP_df.loc[['Africa','Americas','Asia','Europe','Oceania'], :]
NP_df = NP_df.T

NP_df["World"] = NP_df.sum(axis=1)
NP_df = NP_df.sort_values(by="World", ascending=True)
NP_df["Min"] = NP_df.min(axis=1)
NP_df["Max"] = NP_df.max(axis=1)

# %%
# Setting up figure and axes
fig = plt.figure(figsize=(10,5)) # create figure
gs = fig.add_gridspec(1, 1)
gs.update(wspace=0, hspace=0)
ax0 = fig.add_subplot(gs[0, 0])

# Change background color
background_color = "#fbfbfb"
fig.patch.set_facecolor(background_color) # figure background color
ax0.set_facecolor(background_color) # axes background color

y_dummy = np.arange(1,len(NP_df.index)+1)

ax0.hlines(y=y_dummy, xmin=NP_df["Min"], xmax=NP_df["Max"], color='grey', alpha=0.4, zorder=3)
ax0.scatter(NP_df['World'], y_dummy, color='red', label='World')
ax0.scatter(NP_df['Africa'], y_dummy, color='green', label='Africa')
ax0.scatter(NP_df['Americas'], y_dummy, color='blue', label='Americas')
ax0.scatter(NP_df['Asia'], y_dummy, color='orange', label='Asia')
ax0.scatter(NP_df['Europe'], y_dummy, color='skyblue', label='Europe')
ax0.scatter(NP_df['Oceania'], y_dummy, color='magenta', label='Oceania')

y_label = list(NP_df.index)
y_label.insert(0, "")
ax0.yaxis.set_major_locator(mtick.MultipleLocator(1))
ax0.set_yticklabels(y_label)
ax0.set_xticklabels([])
ax0.tick_params(bottom=False)
   
ax0.text(-100, 14, 
         'Visualization Neuroticism Personality traits across Countries (by Continent)', 
         fontsize=20, fontweight='bold', fontfamily='serif')



ax0.legend(loc='lower center', ncol=7, bbox_to_anchor=(0.53, -0.1))

for s in ["top","right", "left", "bottom"]:
    ax0.spines[s].set_visible(False)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
display(continents[['EST1','EST2','EST3','EST4','EST5','EST6','EST7','EST8','EST9','EST10','region']].groupby(['region']).agg(["min","max",'mean','sum']).style.background_gradient(cmap="GnBu"))
# Out:
# <style  type="text/css" >
# #T_03012_row0_col0,#T_03012_row0_col1,#T_03012_row0_col2,#T_03012_row0_col3,#T_03012_row0_col4,#T_03012_row0_col5,#T_03012_row0_col7,#T_03012_row0_col8,#T_03012_row0_col9,#T_03012_row0_col10,#T_03012_row0_col11,#T_03012_row0_col12,#T_03012_row0_col13,#T_03012_row0_col15,#T_03012_row0_col16,#T_03012_row0_col17,#T_03012_row0_col19,#T_03012_row0_col20,#T_03012_row0_col21,#T_03012_row0_col23,#T_03012_row0_col24,#T_03012_row0_col25,#T_03012_row0_col26,#T_03012_row0_col27,#T_03012_row0_col28,#T_03012_row0_col29,#T_03012_row0_col31,#T_03012_row0_col32,#T_03012_row0_col33,#T_03012_row0_col34,#T_03012_row0_col35,#T_03012_row0_col36,#T_03012_row0_col37,#T_03012_row0_col39,#T_03012_row1_col0,#T_03012_row1_col1,#T_03012_row1_col4,#T_03012_row1_col5,#T_03012_row1_col8,#T_03012_row1_col9,#T_03012_row1_col12,#T_03012_row1_col13,#T_03012_row1_col16,#T_03012_row1_col17,#T_03012_row1_col18,#T_03012_row1_col20,#T_03012_row1_col21,#T_03012_row1_col24,#T_03012_row1_col25,#T_03012_row1_col28,#T_03012_row1_col29,#T_03012_row1_col30,#T_03012_row1_col32,#T_03012_row1_col33,#T_03012_row1_col36,#T_03012_row1_col37,#T_03012_row2_col0,#T_03012_row2_col1,#T_03012_row2_col4,#T_03012_row2_col5,#T_03012_row2_col8,#T_03012_row2_col9,#T_03012_row2_col12,#T_03012_row2_col13,#T_03012_row2_col16,#T_03012_row2_col17,#T_03012_row2_col20,#T_03012_row2_col21,#T_03012_row2_col24,#T_03012_row2_col25,#T_03012_row2_col28,#T_03012_row2_col29,#T_03012_row2_col32,#T_03012_row2_col33,#T_03012_row2_col36,#T_03012_row2_col37,#T_03012_row3_col0,#T_03012_row3_col1,#T_03012_row3_col4,#T_03012_row3_col5,#T_03012_row3_col6,#T_03012_row3_col8,#T_03012_row3_col9,#T_03012_row3_col12,#T_03012_row3_col13,#T_03012_row3_col14,#T_03012_row3_col16,#T_03012_row3_col17,#T_03012_row3_col20,#T_03012_row3_col21,#T_03012_row3_col24,#T_03012_row3_col25,#T_03012_row3_col28,#T_03012_row3_col29,#T_03012_row3_col32,#T_03012_row3_col33,#T_03012_row3_col36,#T_03012_row3_col37,#T_03012_row4_col0,#T_03012_row4_col1,#T_03012_row4_col4,#T_03012_row4_col5,#T_03012_row4_col8,#T_03012_row4_col9,#T_03012_row4_col12,#T_03012_row4_col13,#T_03012_row4_col16,#T_03012_row4_col17,#T_03012_row4_col20,#T_03012_row4_col21,#T_03012_row4_col22,#T_03012_row4_col24,#T_03012_row4_col25,#T_03012_row4_col28,#T_03012_row4_col29,#T_03012_row4_col30,#T_03012_row4_col32,#T_03012_row4_col33,#T_03012_row4_col36,#T_03012_row4_col37,#T_03012_row4_col38{
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }#T_03012_row0_col6{
#             background-color:  #56b7d0;
#             color:  #000000;
#         }#T_03012_row0_col14{
#             background-color:  #1d7eb7;
#             color:  #000000;
#         }#T_03012_row0_col18{
#             background-color:  #3496c3;
#             color:  #000000;
#         }#T_03012_row0_col22{
#             background-color:  #ceecc8;
#             color:  #000000;
#         }#T_03012_row0_col30{
#             background-color:  #d5efcf;
#             color:  #000000;
#         }#T_03012_row0_col38{
#             background-color:  #c8eac3;
#             color:  #000000;
#         }#T_03012_row1_col2,#T_03012_row1_col3,#T_03012_row1_col7,#T_03012_row1_col10,#T_03012_row1_col11,#T_03012_row1_col15,#T_03012_row1_col19,#T_03012_row1_col23,#T_03012_row1_col27,#T_03012_row1_col31,#T_03012_row1_col35,#T_03012_row1_col39,#T_03012_row2_col14,#T_03012_row2_col18,#T_03012_row2_col22,#T_03012_row2_col26,#T_03012_row2_col30,#T_03012_row3_col38,#T_03012_row4_col6,#T_03012_row4_col34{
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_03012_row1_col6{
#             background-color:  #b4e2ba;
#             color:  #000000;
#         }#T_03012_row1_col14{
#             background-color:  #f6fcef;
#             color:  #000000;
#         }#T_03012_row1_col22,#T_03012_row1_col38{
#             background-color:  #f3faec;
#             color:  #000000;
#         }#T_03012_row1_col26{
#             background-color:  #e6f5e0;
#             color:  #000000;
#         }#T_03012_row1_col34,#T_03012_row2_col10{
#             background-color:  #cdebc6;
#             color:  #000000;
#         }#T_03012_row2_col2{
#             background-color:  #87d1c0;
#             color:  #000000;
#         }#T_03012_row2_col3,#T_03012_row2_col11{
#             background-color:  #dff3da;
#             color:  #000000;
#         }#T_03012_row2_col6,#T_03012_row3_col30{
#             background-color:  #81cec2;
#             color:  #000000;
#         }#T_03012_row2_col7,#T_03012_row2_col35{
#             background-color:  #dff2da;
#             color:  #000000;
#         }#T_03012_row2_col15,#T_03012_row2_col39{
#             background-color:  #ddf2d8;
#             color:  #000000;
#         }#T_03012_row2_col19,#T_03012_row2_col31{
#             background-color:  #dcf1d6;
#             color:  #000000;
#         }#T_03012_row2_col23,#T_03012_row2_col27{
#             background-color:  #ddf2d7;
#             color:  #000000;
#         }#T_03012_row2_col34{
#             background-color:  #e0f3db;
#             color:  #000000;
#         }#T_03012_row2_col38,#T_03012_row4_col2{
#             background-color:  #3c9fc8;
#             color:  #000000;
#         }#T_03012_row3_col2{
#             background-color:  #8bd2bf;
#             color:  #000000;
#         }#T_03012_row3_col3{
#             background-color:  #c7e9c3;
#             color:  #000000;
#         }#T_03012_row3_col7{
#             background-color:  #c5e8c2;
#             color:  #000000;
#         }#T_03012_row3_col10{
#             background-color:  #8fd4bd;
#             color:  #000000;
#         }#T_03012_row3_col11{
#             background-color:  #c6e9c2;
#             color:  #000000;
#         }#T_03012_row3_col15,#T_03012_row3_col35{
#             background-color:  #c4e8c1;
#             color:  #000000;
#         }#T_03012_row3_col18{
#             background-color:  #1b7bb6;
#             color:  #000000;
#         }#T_03012_row3_col19{
#             background-color:  #bbe4bd;
#             color:  #000000;
#         }#T_03012_row3_col22{
#             background-color:  #d7efd1;
#             color:  #000000;
#         }#T_03012_row3_col23{
#             background-color:  #c3e7c1;
#             color:  #000000;
#         }#T_03012_row3_col26,#T_03012_row4_col18{
#             background-color:  #9fdab8;
#             color:  #000000;
#         }#T_03012_row3_col27{
#             background-color:  #c2e7c0;
#             color:  #000000;
#         }#T_03012_row3_col31,#T_03012_row4_col10{
#             background-color:  #bfe6bf;
#             color:  #000000;
#         }#T_03012_row3_col34{
#             background-color:  #79cbc5;
#             color:  #000000;
#         }#T_03012_row3_col39{
#             background-color:  #bee6bf;
#             color:  #000000;
#         }#T_03012_row4_col3,#T_03012_row4_col7,#T_03012_row4_col15,#T_03012_row4_col23,#T_03012_row4_col27,#T_03012_row4_col31,#T_03012_row4_col35,#T_03012_row4_col39{
#             background-color:  #e8f6e2;
#             color:  #000000;
#         }#T_03012_row4_col11{
#             background-color:  #e9f6e3;
#             color:  #000000;
#         }#T_03012_row4_col14{
#             background-color:  #d9f0d3;
#             color:  #000000;
#         }#T_03012_row4_col19{
#             background-color:  #e7f6e2;
#             color:  #000000;
#         }#T_03012_row4_col26{
#             background-color:  #d8f0d3;
#             color:  #000000;
#         }</style><table id="T_03012_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="4">EST1</th>        <th class="col_heading level0 col4" colspan="4">EST2</th>        <th class="col_heading level0 col8" colspan="4">EST3</th>        <th class="col_heading level0 col12" colspan="4">EST4</th>        <th class="col_heading level0 col16" colspan="4">EST5</th>        <th class="col_heading level0 col20" colspan="4">EST6</th>        <th class="col_heading level0 col24" colspan="4">EST7</th>        <th class="col_heading level0 col28" colspan="4">EST8</th>        <th class="col_heading level0 col32" colspan="4">EST9</th>        <th class="col_heading

# %%
continents[['EST1','EST2','EST3','EST4','EST5','EST6','EST7','EST8','EST9','EST10','dateload','region']].groupby(['region']).agg(["sum"]).plot(kind="line",color =["orange","blue","green",'red','magenta','pink','skyblue','yellow','purple','black'])
plt.title("Sum : Neuroticism Personality traits across Countries (by Continent)", fontsize=20)
plt.ylabel("Neuroticism Personality",fontsize=10)
plt.xlabel(" ")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 3.3. Agreeable Personality

# %%
AP_lst = ['AGR1','AGR2','AGR3','AGR4','AGR5','AGR6','AGR7','AGR8','AGR9','AGR10'] 
AP_df = continents.groupby(["region"])[AP_lst].count()
AP_df.columns = ['I feel little concern for others','I am interested in people','I insult people','I sympathize with others feelings',
                'I am not interested in other peoples problems','I have a soft heart',
                'I am not really interested in others','I take time out for others',
                'I feel others emotions','I make people feel at ease']
AP_df = AP_df.loc[['Africa','Americas','Asia','Europe','Oceania'], :]
AP_df = AP_df.T

AP_df["World"] = AP_df.sum(axis=1)
AP_df = AP_df.sort_values(by="World", ascending=True)
AP_df["Min"] = AP_df.min(axis=1)
AP_df["Max"] = AP_df.max(axis=1)

# %%
# Setting up figure and axes
fig = plt.figure(figsize=(10,5)) # create figure
gs = fig.add_gridspec(1, 1)
gs.update(wspace=0, hspace=0)
ax0 = fig.add_subplot(gs[0, 0])

# Change background color
background_color = "#fbfbfb"
fig.patch.set_facecolor(background_color) # figure background color
ax0.set_facecolor(background_color) # axes background color

y_dummy = np.arange(1,len(AP_df.index)+1)

ax0.hlines(y=y_dummy, xmin=AP_df["Min"], xmax=AP_df["Max"], color='grey', alpha=0.4, zorder=3)
ax0.scatter(AP_df['World'], y_dummy, color='red', label='World')
ax0.scatter(AP_df['Africa'], y_dummy, color='green', label='Africa')
ax0.scatter(AP_df['Americas'], y_dummy, color='blue', label='Americas')
ax0.scatter(AP_df['Asia'], y_dummy, color='orange', label='Asia')
ax0.scatter(AP_df['Europe'], y_dummy, color='skyblue', label='Europe')
ax0.scatter(AP_df['Oceania'], y_dummy, color='magenta', label='Oceania')

y_label = list(AP_df.index)
y_label.insert(0, "")
ax0.yaxis.set_major_locator(mtick.MultipleLocator(1))
ax0.set_yticklabels(y_label)
ax0.set_xticklabels([])
ax0.tick_params(bottom=False)
   
ax0.text(-100, 14, 
         'Visualization Agreeable Personality traits across Countries (by Continent)', 
         fontsize=20, fontweight='bold', fontfamily='serif')



ax0.legend(loc='lower center', ncol=7, bbox_to_anchor=(0.53, -0.1))

for s in ["top","right", "left", "bottom"]:
    ax0.spines[s].set_visible(False)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
display(continents[['AGR1','AGR2','AGR3','AGR4','AGR5','AGR6','AGR7','AGR8','AGR9','AGR10','region']].groupby(['region']).agg(["min","max",'mean','sum']).style.background_gradient(cmap="GnBu"))
# Out:
# <style  type="text/css" >
# #T_ebf62_row0_col0,#T_ebf62_row0_col1,#T_ebf62_row0_col3,#T_ebf62_row0_col4,#T_ebf62_row0_col5,#T_ebf62_row0_col7,#T_ebf62_row0_col8,#T_ebf62_row0_col9,#T_ebf62_row0_col10,#T_ebf62_row0_col11,#T_ebf62_row0_col12,#T_ebf62_row0_col13,#T_ebf62_row0_col15,#T_ebf62_row0_col16,#T_ebf62_row0_col17,#T_ebf62_row0_col18,#T_ebf62_row0_col19,#T_ebf62_row0_col20,#T_ebf62_row0_col21,#T_ebf62_row0_col23,#T_ebf62_row0_col24,#T_ebf62_row0_col25,#T_ebf62_row0_col27,#T_ebf62_row0_col28,#T_ebf62_row0_col29,#T_ebf62_row0_col31,#T_ebf62_row0_col32,#T_ebf62_row0_col33,#T_ebf62_row0_col35,#T_ebf62_row0_col36,#T_ebf62_row0_col37,#T_ebf62_row0_col39,#T_ebf62_row1_col0,#T_ebf62_row1_col1,#T_ebf62_row1_col2,#T_ebf62_row1_col4,#T_ebf62_row1_col5,#T_ebf62_row1_col8,#T_ebf62_row1_col9,#T_ebf62_row1_col12,#T_ebf62_row1_col13,#T_ebf62_row1_col16,#T_ebf62_row1_col17,#T_ebf62_row1_col20,#T_ebf62_row1_col21,#T_ebf62_row1_col24,#T_ebf62_row1_col25,#T_ebf62_row1_col26,#T_ebf62_row1_col28,#T_ebf62_row1_col29,#T_ebf62_row1_col32,#T_ebf62_row1_col33,#T_ebf62_row1_col36,#T_ebf62_row1_col37,#T_ebf62_row2_col0,#T_ebf62_row2_col1,#T_ebf62_row2_col4,#T_ebf62_row2_col5,#T_ebf62_row2_col6,#T_ebf62_row2_col8,#T_ebf62_row2_col9,#T_ebf62_row2_col12,#T_ebf62_row2_col13,#T_ebf62_row2_col16,#T_ebf62_row2_col17,#T_ebf62_row2_col20,#T_ebf62_row2_col21,#T_ebf62_row2_col24,#T_ebf62_row2_col25,#T_ebf62_row2_col28,#T_ebf62_row2_col29,#T_ebf62_row2_col30,#T_ebf62_row2_col32,#T_ebf62_row2_col33,#T_ebf62_row2_col36,#T_ebf62_row2_col37,#T_ebf62_row3_col0,#T_ebf62_row3_col1,#T_ebf62_row3_col4,#T_ebf62_row3_col5,#T_ebf62_row3_col8,#T_ebf62_row3_col9,#T_ebf62_row3_col12,#T_ebf62_row3_col13,#T_ebf62_row3_col14,#T_ebf62_row3_col16,#T_ebf62_row3_col17,#T_ebf62_row3_col20,#T_ebf62_row3_col21,#T_ebf62_row3_col22,#T_ebf62_row3_col24,#T_ebf62_row3_col25,#T_ebf62_row3_col28,#T_ebf62_row3_col29,#T_ebf62_row3_col32,#T_ebf62_row3_col33,#T_ebf62_row3_col34,#T_ebf62_row3_col36,#T_ebf62_row3_col37,#T_ebf62_row3_col38,#T_ebf62_row4_col0,#T_ebf62_row4_col1,#T_ebf62_row4_col4,#T_ebf62_row4_col5,#T_ebf62_row4_col8,#T_ebf62_row4_col9,#T_ebf62_row4_col12,#T_ebf62_row4_col13,#T_ebf62_row4_col16,#T_ebf62_row4_col17,#T_ebf62_row4_col20,#T_ebf62_row4_col21,#T_ebf62_row4_col24,#T_ebf62_row4_col25,#T_ebf62_row4_col28,#T_ebf62_row4_col29,#T_ebf62_row4_col32,#T_ebf62_row4_col33,#T_ebf62_row4_col36,#T_ebf62_row4_col37{
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }#T_ebf62_row0_col2{
#             background-color:  #afe0b8;
#             color:  #000000;
#         }#T_ebf62_row0_col6{
#             background-color:  #d8f0d3;
#             color:  #000000;
#         }#T_ebf62_row0_col14{
#             background-color:  #084b8d;
#             color:  #f1f1f1;
#         }#T_ebf62_row0_col22{
#             background-color:  #085c9f;
#             color:  #f1f1f1;
#         }#T_ebf62_row0_col26{
#             background-color:  #9ed9b8;
#             color:  #000000;
#         }#T_ebf62_row0_col30,#T_ebf62_row3_col27{
#             background-color:  #bfe6bf;
#             color:  #000000;
#         }#T_ebf62_row0_col34{
#             background-color:  #0862a5;
#             color:  #f1f1f1;
#         }#T_ebf62_row0_col38,#T_ebf62_row1_col3,#T_ebf62_row1_col7,#T_ebf62_row1_col11,#T_ebf62_row1_col14,#T_ebf62_row1_col15,#T_ebf62_row1_col19,#T_ebf62_row1_col23,#T_ebf62_row1_col27,#T_ebf62_row1_col30,#T_ebf62_row1_col31,#T_ebf62_row1_col35,#T_ebf62_row1_col39,#T_ebf62_row2_col2,#T_ebf62_row2_col18,#T_ebf62_row2_col22,#T_ebf62_row2_col26,#T_ebf62_row2_col34,#T_ebf62_row4_col6,#T_ebf62_row4_col10{
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_ebf62_row1_col6{
#             background-color:  #2081b8;
#             color:  #000000;
#         }#T_ebf62_row1_col10,#T_ebf62_row1_col22{
#             background-color:  #3091c1;
#             color:  #000000;
#         }#T_ebf62_row1_col18{
#             background-color:  #f2faeb;
#             color:  #000000;
#         }#T_ebf62_row1_col34{
#             background-color:  #49add0;
#             color:  #000000;
#         }#T_ebf62_row1_col38{
#             background-color:  #62becc;
#             color:  #000000;
#         }#T_ebf62_row2_col3{
#             background-color:  #d6efd0;
#             color:  #000000;
#         }#T_ebf62_row2_col7{
#             background-color:  #dff3da;
#             color:  #000000;
#         }#T_ebf62_row2_col10{
#             background-color:  #68c1ca;
#             color:  #000000;
#         }#T_ebf62_row2_col11,#T_ebf62_row2_col15,#T_ebf62_row2_col39{
#             background-color:  #dff2da;
#             color:  #000000;
#         }#T_ebf62_row2_col14{
#             background-color:  #50b4d2;
#             color:  #000000;
#         }#T_ebf62_row2_col19{
#             background-color:  #dcf1d7;
#             color:  #000000;
#         }#T_ebf62_row2_col23,#T_ebf62_row2_col35{
#             background-color:  #def2d9;
#             color:  #000000;
#         }#T_ebf62_row2_col27{
#             background-color:  #dcf1d6;
#             color:  #000000;
#         }#T_ebf62_row2_col31{
#             background-color:  #e0f3db;
#             color:  #000000;
#         }#T_ebf62_row2_col38{
#             background-color:  #aadeb6;
#             color:  #000000;
#         }#T_ebf62_row3_col2{
#             background-color:  #c0e6c0;
#             color:  #000000;
#         }#T_ebf62_row3_col3{
#             background-color:  #bbe4bd;
#             color:  #000000;
#         }#T_ebf62_row3_col6{
#             background-color:  #8dd3be;
#             color:  #000000;
#         }#T_ebf62_row3_col7{
#             background-color:  #c5e8c2;
#             color:  #000000;
#         }#T_ebf62_row3_col10{
#             background-color:  #0867ab;
#             color:  #f1f1f1;
#         }#T_ebf62_row3_col11,#T_ebf62_row3_col19{
#             background-color:  #c2e7c0;
#             color:  #000000;
#         }#T_ebf62_row3_col15,#T_ebf62_row3_col39{
#             background-color:  #c7e9c3;
#             color:  #000000;
#         }#T_ebf62_row3_col18{
#             background-color:  #b7e3bc;
#             color:  #000000;
#         }#T_ebf62_row3_col23,#T_ebf62_row3_col31{
#             background-color:  #c8eac3;
#             color:  #000000;
#         }#T_ebf62_row3_col26{
#             background-color:  #9fdab8;
#             color:  #000000;
#         }#T_ebf62_row3_col30,#T_ebf62_row4_col11{
#             background-color:  #e6f6e1;
#             color:  #000000;
#         }#T_ebf62_row3_col35{
#             background-color:  #c6e9c2;
#             color:  #000000;
#         }#T_ebf62_row4_col2{
#             background-color:  #eef9e8;
#             color:  #000000;
#         }#T_ebf62_row4_col3,#T_ebf62_row4_col7,#T_ebf62_row4_col15,#T_ebf62_row4_col19,#T_ebf62_row4_col23,#T_ebf62_row4_col27,#T_ebf62_row4_col31,#T_ebf62_row4_col35{
#             background-color:  #e8f6e2;
#             color:  #000000;
#         }#T_ebf62_row4_col14{
#             background-color:  #0861a4;
#             color:  #f1f1f1;
#         }#T_ebf62_row4_col18{
#             background-color:  #f6fbef;
#             color:  #000000;
#         }#T_ebf62_row4_col22{
#             background-color:  #69c2ca;
#             color:  #000000;
#         }#T_ebf62_row4_col26{
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }#T_ebf62_row4_col30{
#             background-color:  #0868ac;
#             color:  #f1f1f1;
#         }#T_ebf62_row4_col34{
#             background-color:  #72c7c7;
#             color:  #000000;
#         }#T_ebf62_row4_col38{
#             background-color:  #bee6bf;
#             color:  #000000;
#         }#T_ebf62_row4_col39{
#             background-color:  #e9f6e3;
#             color:  #000000;
#         }</style><table id="T_ebf62_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="4">AGR1</th>        <th class="col_heading level0 col4" colspan="4">AGR2</th>        <th class="col_heading level0 col8" colspan="4">AGR3</th>        <th class="col_heading level0 col12" colspan="4">AGR4</th>        <th class="col_heading level0 col16"

# %%
continents[['AGR1','AGR2','AGR3','AGR4','AGR5','AGR6','AGR7','AGR8','AGR9','AGR10','dateload','region']].groupby(['region']).agg(["sum"]).plot(kind="line",color =["orange","blue","green",'red','magenta','pink','skyblue','yellow','purple','black'])
plt.title("Sum : Agreeable Personality traits across Countries (by Continent)", fontsize=20)
plt.ylabel("Agreeable Personality",fontsize=10)
plt.xlabel(" ")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 3.4. Conscientious Personality

# %%
CP_lst = ['CSN1','CSN2','CSN3','CSN4','CSN5','CSN6','CSN7','CSN8','CSN9','CSN10'] 
CP_df = continents.groupby(["region"])[CP_lst].count()
CP_df.columns = ['I am always prepared','I leave my belongings around',
                'I pay attention to details','I make a mess of things',
                'I get chores done right away','I often forget to put things back in their proper place',
                'I like order','I shirk my duties',
                'I follow a schedule','I am exacting in my work']
CP_df = CP_df.loc[['Africa','Americas','Asia','Europe','Oceania'], :]
CP_df = CP_df.T

CP_df["World"] = CP_df.sum(axis=1)
CP_df = CP_df.sort_values(by="World", ascending=True)
CP_df["Min"] = CP_df.min(axis=1)
CP_df["Max"] = CP_df.max(axis=1)

# %%
# Setting up figure and axes
fig = plt.figure(figsize=(10,5)) # create figure
gs = fig.add_gridspec(1, 1)
gs.update(wspace=0, hspace=0)
ax0 = fig.add_subplot(gs[0, 0])

# Change background color
background_color = "#fbfbfb"
fig.patch.set_facecolor(background_color) # figure background color
ax0.set_facecolor(background_color) # axes background color

y_dummy = np.arange(1,len(CP_df.index)+1)

ax0.hlines(y=y_dummy, xmin=CP_df["Min"], xmax=CP_df["Max"], color='grey', alpha=0.4, zorder=3)
ax0.scatter(CP_df['World'], y_dummy, color='red', label='World')
ax0.scatter(CP_df['Africa'], y_dummy, color='green', label='Africa')
ax0.scatter(CP_df['Americas'], y_dummy, color='blue', label='Americas')
ax0.scatter(CP_df['Asia'], y_dummy, color='orange', label='Asia')
ax0.scatter(CP_df['Europe'], y_dummy, color='skyblue', label='Europe')
ax0.scatter(CP_df['Oceania'], y_dummy, color='magenta', label='Oceania')

y_label = list(CP_df.index)
y_label.insert(0, "")
ax0.yaxis.set_major_locator(mtick.MultipleLocator(1))
ax0.set_yticklabels(y_label)
ax0.set_xticklabels([])
ax0.tick_params(bottom=False)
   
ax0.text(-100, 14, 
         'Visualization Conscientious Personality traits across Countries (by Continent)', 
         fontsize=20, fontweight='bold', fontfamily='serif')



ax0.legend(loc='lower center', ncol=7, bbox_to_anchor=(0.53, -0.1))

for s in ["top","right", "left", "bottom"]:
    ax0.spines[s].set_visible(False)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
display(continents[['CSN1','CSN2','CSN3','CSN4','CSN5','CSN6','CSN7','CSN8','CSN9','CSN10','region']].groupby(['region']).agg(["min","max",'mean','sum']).style.background_gradient(cmap="GnBu"))
# Out:
# <style  type="text/css" >
# #T_ac3f2_row0_col0,#T_ac3f2_row0_col1,#T_ac3f2_row0_col3,#T_ac3f2_row0_col4,#T_ac3f2_row0_col5,#T_ac3f2_row0_col6,#T_ac3f2_row0_col7,#T_ac3f2_row0_col8,#T_ac3f2_row0_col9,#T_ac3f2_row0_col11,#T_ac3f2_row0_col12,#T_ac3f2_row0_col13,#T_ac3f2_row0_col14,#T_ac3f2_row0_col15,#T_ac3f2_row0_col16,#T_ac3f2_row0_col17,#T_ac3f2_row0_col19,#T_ac3f2_row0_col20,#T_ac3f2_row0_col21,#T_ac3f2_row0_col22,#T_ac3f2_row0_col23,#T_ac3f2_row0_col24,#T_ac3f2_row0_col25,#T_ac3f2_row0_col27,#T_ac3f2_row0_col28,#T_ac3f2_row0_col29,#T_ac3f2_row0_col30,#T_ac3f2_row0_col31,#T_ac3f2_row0_col32,#T_ac3f2_row0_col33,#T_ac3f2_row0_col35,#T_ac3f2_row0_col36,#T_ac3f2_row0_col37,#T_ac3f2_row0_col39,#T_ac3f2_row1_col0,#T_ac3f2_row1_col1,#T_ac3f2_row1_col4,#T_ac3f2_row1_col5,#T_ac3f2_row1_col8,#T_ac3f2_row1_col9,#T_ac3f2_row1_col12,#T_ac3f2_row1_col13,#T_ac3f2_row1_col16,#T_ac3f2_row1_col17,#T_ac3f2_row1_col20,#T_ac3f2_row1_col21,#T_ac3f2_row1_col24,#T_ac3f2_row1_col25,#T_ac3f2_row1_col28,#T_ac3f2_row1_col29,#T_ac3f2_row1_col32,#T_ac3f2_row1_col33,#T_ac3f2_row1_col36,#T_ac3f2_row1_col37,#T_ac3f2_row2_col0,#T_ac3f2_row2_col1,#T_ac3f2_row2_col4,#T_ac3f2_row2_col5,#T_ac3f2_row2_col8,#T_ac3f2_row2_col9,#T_ac3f2_row2_col10,#T_ac3f2_row2_col12,#T_ac3f2_row2_col13,#T_ac3f2_row2_col16,#T_ac3f2_row2_col17,#T_ac3f2_row2_col20,#T_ac3f2_row2_col21,#T_ac3f2_row2_col24,#T_ac3f2_row2_col25,#T_ac3f2_row2_col26,#T_ac3f2_row2_col28,#T_ac3f2_row2_col29,#T_ac3f2_row2_col32,#T_ac3f2_row2_col33,#T_ac3f2_row2_col36,#T_ac3f2_row2_col37,#T_ac3f2_row2_col38,#T_ac3f2_row3_col0,#T_ac3f2_row3_col1,#T_ac3f2_row3_col2,#T_ac3f2_row3_col4,#T_ac3f2_row3_col5,#T_ac3f2_row3_col8,#T_ac3f2_row3_col9,#T_ac3f2_row3_col12,#T_ac3f2_row3_col13,#T_ac3f2_row3_col16,#T_ac3f2_row3_col17,#T_ac3f2_row3_col18,#T_ac3f2_row3_col20,#T_ac3f2_row3_col21,#T_ac3f2_row3_col24,#T_ac3f2_row3_col25,#T_ac3f2_row3_col28,#T_ac3f2_row3_col29,#T_ac3f2_row3_col32,#T_ac3f2_row3_col33,#T_ac3f2_row3_col34,#T_ac3f2_row3_col36,#T_ac3f2_row3_col37,#T_ac3f2_row4_col0,#T_ac3f2_row4_col1,#T_ac3f2_row4_col4,#T_ac3f2_row4_col5,#T_ac3f2_row4_col8,#T_ac3f2_row4_col9,#T_ac3f2_row4_col12,#T_ac3f2_row4_col13,#T_ac3f2_row4_col16,#T_ac3f2_row4_col17,#T_ac3f2_row4_col20,#T_ac3f2_row4_col21,#T_ac3f2_row4_col24,#T_ac3f2_row4_col25,#T_ac3f2_row4_col28,#T_ac3f2_row4_col29,#T_ac3f2_row4_col32,#T_ac3f2_row4_col33,#T_ac3f2_row4_col36,#T_ac3f2_row4_col37{
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }#T_ac3f2_row0_col2{
#             background-color:  #0863a7;
#             color:  #f1f1f1;
#         }#T_ac3f2_row0_col10,#T_ac3f2_row0_col18,#T_ac3f2_row0_col26,#T_ac3f2_row0_col38,#T_ac3f2_row1_col2,#T_ac3f2_row1_col3,#T_ac3f2_row1_col7,#T_ac3f2_row1_col11,#T_ac3f2_row1_col15,#T_ac3f2_row1_col19,#T_ac3f2_row1_col23,#T_ac3f2_row1_col27,#T_ac3f2_row1_col31,#T_ac3f2_row1_col34,#T_ac3f2_row1_col35,#T_ac3f2_row1_col39,#T_ac3f2_row3_col6,#T_ac3f2_row3_col14,#T_ac3f2_row3_col22,#T_ac3f2_row3_col30{
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_ac3f2_row0_col34{
#             background-color:  #7fcdc3;
#             color:  #000000;
#         }#T_ac3f2_row1_col6{
#             background-color:  #0861a4;
#             color:  #f1f1f1;
#         }#T_ac3f2_row1_col10{
#             background-color:  #1576b3;
#             color:  #f1f1f1;
#         }#T_ac3f2_row1_col14{
#             background-color:  #51b5d2;
#             color:  #000000;
#         }#T_ac3f2_row1_col18{
#             background-color:  #a2dbb7;
#             color:  #000000;
#         }#T_ac3f2_row1_col22{
#             background-color:  #3ea1c9;
#             color:  #000000;
#         }#T_ac3f2_row1_col26,#T_ac3f2_row2_col14{
#             background-color:  #085093;
#             color:  #f1f1f1;
#         }#T_ac3f2_row1_col30,#T_ac3f2_row4_col3,#T_ac3f2_row4_col7,#T_ac3f2_row4_col23,#T_ac3f2_row4_col31{
#             background-color:  #e8f6e2;
#             color:  #000000;
#         }#T_ac3f2_row1_col38{
#             background-color:  #57b8d0;
#             color:  #000000;
#         }#T_ac3f2_row2_col2{
#             background-color:  #2d8fbf;
#             color:  #000000;
#         }#T_ac3f2_row2_col3,#T_ac3f2_row2_col35{
#             background-color:  #dff2da;
#             color:  #000000;
#         }#T_ac3f2_row2_col6{
#             background-color:  #bee6bf;
#             color:  #000000;
#         }#T_ac3f2_row2_col7,#T_ac3f2_row4_col10{
#             background-color:  #e0f3db;
#             color:  #000000;
#         }#T_ac3f2_row2_col11,#T_ac3f2_row2_col39{
#             background-color:  #dff3da;
#             color:  #000000;
#         }#T_ac3f2_row2_col15,#T_ac3f2_row2_col31{
#             background-color:  #ddf2d8;
#             color:  #000000;
#         }#T_ac3f2_row2_col18{
#             background-color:  #084182;
#             color:  #f1f1f1;
#         }#T_ac3f2_row2_col19{
#             background-color:  #dcf1d7;
#             color:  #000000;
#         }#T_ac3f2_row2_col22{
#             background-color:  #085598;
#             color:  #f1f1f1;
#         }#T_ac3f2_row2_col23{
#             background-color:  #def2d9;
#             color:  #000000;
#         }#T_ac3f2_row2_col27{
#             background-color:  #e1f3dc;
#             color:  #000000;
#         }#T_ac3f2_row2_col30{
#             background-color:  #9cd9b9;
#             color:  #000000;
#         }#T_ac3f2_row2_col34{
#             background-color:  #1d7eb7;
#             color:  #000000;
#         }#T_ac3f2_row3_col3,#T_ac3f2_row3_col27{
#             background-color:  #c7e9c3;
#             color:  #000000;
#         }#T_ac3f2_row3_col7{
#             background-color:  #c3e7c1;
#             color:  #000000;
#         }#T_ac3f2_row3_col10{
#             background-color:  #b2e1b9;
#             color:  #000000;
#         }#T_ac3f2_row3_col11,#T_ac3f2_row3_col39{
#             background-color:  #c6e9c2;
#             color:  #000000;
#         }#T_ac3f2_row3_col15{
#             background-color:  #bfe6bf;
#             color:  #000000;
#         }#T_ac3f2_row3_col19{
#             background-color:  #c9eac4;
#             color:  #000000;
#         }#T_ac3f2_row3_col23{
#             background-color:  #c2e7c0;
#             color:  #000000;
#         }#T_ac3f2_row3_col26{
#             background-color:  #62becc;
#             color:  #000000;
#         }#T_ac3f2_row3_col31{
#             background-color:  #bce5be;
#             color:  #000000;
#         }#T_ac3f2_row3_col35{
#             background-color:  #ccebc6;
#             color:  #000000;
#         }#T_ac3f2_row3_col38{
#             background-color:  #d8f0d2;
#             color:  #000000;
#         }#T_ac3f2_row4_col2{
#             background-color:  #58b9d0;
#             color:  #000000;
#         }#T_ac3f2_row4_col6{
#             background-color:  #1070b0;
#             color:  #f1f1f1;
#         }#T_ac3f2_row4_col11,#T_ac3f2_row4_col19,#T_ac3f2_row4_col27,#T_ac3f2_row4_col35,#T_ac3f2_row4_col39{
#             background-color:  #e9f6e3;
#             color:  #000000;
#         }#T_ac3f2_row4_col14{
#             background-color:  #379ac5;
#             color:  #000000;
#         }#T_ac3f2_row4_col15{
#             background-color:  #e7f6e2;
#             color:  #000000;
#         }#T_ac3f2_row4_col18{
#             background-color:  #abdeb6;
#             color:  #000000;
#         }#T_ac3f2_row4_col22,#T_ac3f2_row4_col34{
#             background-color:  #7dcdc3;
#             color:  #000000;
#         }#T_ac3f2_row4_col26{
#             background-color:  #2889bc;
#             color:  #000000;
#         }#T_ac3f2_row4_col30{
#             background-color:  #f1faeb;
#             color:  #000000;
#         }#T_ac3f2_row4_col38{
#             background-color:  #d6efd0;
#             color:  #000000;
#         }</style><table id="T_ac3f2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="4">CSN1</th>        <th class="col_heading level0 col4" colspan="4">CSN2</th>        <th class="col_heading level0 col8" colspan="4">CSN3</th>        <th class="col_heading level0 col12" colspan="4">CSN4</th>        <th class="col_heading level0 col16"

# %%
continents[['CSN1','CSN2','CSN3','CSN4','CSN5','CSN6','CSN7','CSN8','CSN9','CSN10','dateload','region']].groupby(['region']).agg(["sum"]).plot(kind="line",color =["orange","blue","green",'red','magenta','pink','skyblue','yellow','purple','black'])
plt.title("Sum : Conscientious Personality traits across Countries (by Continent)", fontsize=20)
plt.ylabel("Conscientious Personality",fontsize=10)
plt.xlabel(" ")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 3.5. Open Personality

# %%
OP_lst = ['OPN1','OPN2','OPN3','OPN4','OPN5','OPN6','OPN7','OPN8','OPN9','OPN10'] 
OP_df = continents.groupby(["region"])[OP_lst].count()
OP_df.columns = ['I have a rich vocabulary','I have difficulty understanding abstract ideas',
                'I have a vivid imagination','I am not interested in abstract ideas',
                'I have excellent ideas','I do not have a good imagination',
                'I am quick to understand things','I use difficult words',
                'I spend time reflecting on things','I am full of ideas']
OP_df = OP_df.loc[['Africa','Americas','Asia','Europe','Oceania'], :]
OP_df = OP_df.T

OP_df["World"] = OP_df.sum(axis=1)
OP_df = OP_df.sort_values(by="World", ascending=True)
OP_df["Min"] = OP_df.min(axis=1)
OP_df["Max"] = OP_df.max(axis=1)

# %%
# Setting up figure and axes
fig = plt.figure(figsize=(10,5)) # create figure
gs = fig.add_gridspec(1, 1)
gs.update(wspace=0, hspace=0)
ax0 = fig.add_subplot(gs[0, 0])

# Change background color
background_color = "#fbfbfb"
fig.patch.set_facecolor(background_color) # figure background color
ax0.set_facecolor(background_color) # axes background color

y_dummy = np.arange(1,len(OP_df.index)+1)

ax0.hlines(y=y_dummy, xmin=OP_df["Min"], xmax=OP_df["Max"], color='grey', alpha=0.4, zorder=3)
ax0.scatter(OP_df['World'], y_dummy, color='red', label='World')
ax0.scatter(OP_df['Africa'], y_dummy, color='green', label='Africa')
ax0.scatter(OP_df['Americas'], y_dummy, color='blue', label='Americas')
ax0.scatter(OP_df['Asia'], y_dummy, color='orange', label='Asia')
ax0.scatter(OP_df['Europe'], y_dummy, color='skyblue', label='Europe')
ax0.scatter(OP_df['Oceania'], y_dummy, color='magenta', label='Oceania')

y_label = list(OP_df.index)
y_label.insert(0, "")
ax0.yaxis.set_major_locator(mtick.MultipleLocator(1))
ax0.set_yticklabels(y_label)
ax0.set_xticklabels([])
ax0.tick_params(bottom=False)
   
ax0.text(-100, 14, 
         'Visualization Open Personality traits across Countries (by Continent)', 
         fontsize=20, fontweight='bold', fontfamily='serif')



ax0.legend(loc='lower center', ncol=7, bbox_to_anchor=(0.53, -0.1))

for s in ["top","right", "left", "bottom"]:
    ax0.spines[s].set_visible(False)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
display(continents[['OPN1','OPN2','OPN3','OPN4','OPN5','OPN6','OPN7','OPN8','OPN9','OPN10','region']].groupby(['region']).agg(["min","max",'mean','sum']).style.background_gradient(cmap="GnBu"))
# Out:
# <style  type="text/css" >
# #T_7d20c_row0_col0,#T_7d20c_row0_col1,#T_7d20c_row0_col3,#T_7d20c_row0_col4,#T_7d20c_row0_col5,#T_7d20c_row0_col7,#T_7d20c_row0_col8,#T_7d20c_row0_col9,#T_7d20c_row0_col11,#T_7d20c_row0_col12,#T_7d20c_row0_col13,#T_7d20c_row0_col15,#T_7d20c_row0_col16,#T_7d20c_row0_col17,#T_7d20c_row0_col19,#T_7d20c_row0_col20,#T_7d20c_row0_col21,#T_7d20c_row0_col22,#T_7d20c_row0_col23,#T_7d20c_row0_col24,#T_7d20c_row0_col25,#T_7d20c_row0_col27,#T_7d20c_row0_col28,#T_7d20c_row0_col29,#T_7d20c_row0_col31,#T_7d20c_row0_col32,#T_7d20c_row0_col33,#T_7d20c_row0_col35,#T_7d20c_row0_col36,#T_7d20c_row0_col37,#T_7d20c_row0_col39,#T_7d20c_row1_col0,#T_7d20c_row1_col1,#T_7d20c_row1_col4,#T_7d20c_row1_col5,#T_7d20c_row1_col8,#T_7d20c_row1_col9,#T_7d20c_row1_col12,#T_7d20c_row1_col13,#T_7d20c_row1_col16,#T_7d20c_row1_col17,#T_7d20c_row1_col20,#T_7d20c_row1_col21,#T_7d20c_row1_col24,#T_7d20c_row1_col25,#T_7d20c_row1_col28,#T_7d20c_row1_col29,#T_7d20c_row1_col32,#T_7d20c_row1_col33,#T_7d20c_row1_col36,#T_7d20c_row1_col37,#T_7d20c_row2_col0,#T_7d20c_row2_col1,#T_7d20c_row2_col2,#T_7d20c_row2_col4,#T_7d20c_row2_col5,#T_7d20c_row2_col8,#T_7d20c_row2_col9,#T_7d20c_row2_col10,#T_7d20c_row2_col12,#T_7d20c_row2_col13,#T_7d20c_row2_col16,#T_7d20c_row2_col17,#T_7d20c_row2_col18,#T_7d20c_row2_col20,#T_7d20c_row2_col21,#T_7d20c_row2_col24,#T_7d20c_row2_col25,#T_7d20c_row2_col26,#T_7d20c_row2_col28,#T_7d20c_row2_col29,#T_7d20c_row2_col30,#T_7d20c_row2_col32,#T_7d20c_row2_col33,#T_7d20c_row2_col34,#T_7d20c_row2_col36,#T_7d20c_row2_col37,#T_7d20c_row2_col38,#T_7d20c_row3_col0,#T_7d20c_row3_col1,#T_7d20c_row3_col4,#T_7d20c_row3_col5,#T_7d20c_row3_col6,#T_7d20c_row3_col8,#T_7d20c_row3_col9,#T_7d20c_row3_col12,#T_7d20c_row3_col13,#T_7d20c_row3_col14,#T_7d20c_row3_col16,#T_7d20c_row3_col17,#T_7d20c_row3_col20,#T_7d20c_row3_col21,#T_7d20c_row3_col24,#T_7d20c_row3_col25,#T_7d20c_row3_col28,#T_7d20c_row3_col29,#T_7d20c_row3_col32,#T_7d20c_row3_col33,#T_7d20c_row3_col36,#T_7d20c_row3_col37,#T_7d20c_row4_col0,#T_7d20c_row4_col1,#T_7d20c_row4_col4,#T_7d20c_row4_col5,#T_7d20c_row4_col8,#T_7d20c_row4_col9,#T_7d20c_row4_col12,#T_7d20c_row4_col13,#T_7d20c_row4_col16,#T_7d20c_row4_col17,#T_7d20c_row4_col20,#T_7d20c_row4_col21,#T_7d20c_row4_col24,#T_7d20c_row4_col25,#T_7d20c_row4_col28,#T_7d20c_row4_col29,#T_7d20c_row4_col32,#T_7d20c_row4_col33,#T_7d20c_row4_col36,#T_7d20c_row4_col37{
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }#T_7d20c_row0_col2{
#             background-color:  #46aace;
#             color:  #000000;
#         }#T_7d20c_row0_col6{
#             background-color:  #c2e7c0;
#             color:  #000000;
#         }#T_7d20c_row0_col10,#T_7d20c_row0_col18,#T_7d20c_row0_col26,#T_7d20c_row0_col38,#T_7d20c_row1_col3,#T_7d20c_row1_col7,#T_7d20c_row1_col11,#T_7d20c_row1_col15,#T_7d20c_row1_col19,#T_7d20c_row1_col23,#T_7d20c_row1_col27,#T_7d20c_row1_col31,#T_7d20c_row1_col35,#T_7d20c_row1_col39,#T_7d20c_row2_col6,#T_7d20c_row2_col14,#T_7d20c_row3_col2,#T_7d20c_row3_col30,#T_7d20c_row3_col34,#T_7d20c_row4_col22{
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_7d20c_row0_col14{
#             background-color:  #98d7ba;
#             color:  #000000;
#         }#T_7d20c_row0_col30,#T_7d20c_row3_col7{
#             background-color:  #c9eac4;
#             color:  #000000;
#         }#T_7d20c_row0_col34{
#             background-color:  #1c7cb6;
#             color:  #000000;
#         }#T_7d20c_row1_col2{
#             background-color:  #51b5d2;
#             color:  #000000;
#         }#T_7d20c_row1_col6{
#             background-color:  #bce5be;
#             color:  #000000;
#         }#T_7d20c_row1_col10{
#             background-color:  #3699c5;
#             color:  #000000;
#         }#T_7d20c_row1_col14,#T_7d20c_row3_col3{
#             background-color:  #bee6bf;
#             color:  #000000;
#         }#T_7d20c_row1_col18{
#             background-color:  #3fa2ca;
#             color:  #000000;
#         }#T_7d20c_row1_col22{
#             background-color:  #5bbacf;
#             color:  #000000;
#         }#T_7d20c_row1_col26,#T_7d20c_row4_col6{
#             background-color:  #8bd2bf;
#             color:  #000000;
#         }#T_7d20c_row1_col30{
#             background-color:  #4aafd1;
#             color:  #000000;
#         }#T_7d20c_row1_col34{
#             background-color:  #0863a7;
#             color:  #f1f1f1;
#         }#T_7d20c_row1_col38{
#             background-color:  #0e6eaf;
#             color:  #f1f1f1;
#         }#T_7d20c_row2_col3{
#             background-color:  #e1f4dc;
#             color:  #000000;
#         }#T_7d20c_row2_col7{
#             background-color:  #dbf1d5;
#             color:  #000000;
#         }#T_7d20c_row2_col11,#T_7d20c_row2_col27{
#             background-color:  #dff3da;
#             color:  #000000;
#         }#T_7d20c_row2_col15{
#             background-color:  #dcf1d7;
#             color:  #000000;
#         }#T_7d20c_row2_col19,#T_7d20c_row2_col39{
#             background-color:  #e0f3db;
#             color:  #000000;
#         }#T_7d20c_row2_col22{
#             background-color:  #085497;
#             color:  #f1f1f1;
#         }#T_7d20c_row2_col23{
#             background-color:  #ddf2d8;
#             color:  #000000;
#         }#T_7d20c_row2_col31{
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }#T_7d20c_row2_col35{
#             background-color:  #e1f3dc;
#             color:  #000000;
#         }#T_7d20c_row3_col10{
#             background-color:  #0868ac;
#             color:  #f1f1f1;
#         }#T_7d20c_row3_col11,#T_7d20c_row3_col27,#T_7d20c_row3_col35{
#             background-color:  #c3e7c1;
#             color:  #000000;
#         }#T_7d20c_row3_col15{
#             background-color:  #c7e9c3;
#             color:  #000000;
#         }#T_7d20c_row3_col18{
#             background-color:  #b7e3bc;
#             color:  #000000;
#         }#T_7d20c_row3_col19,#T_7d20c_row3_col39{
#             background-color:  #c6e9c2;
#             color:  #000000;
#         }#T_7d20c_row3_col22,#T_7d20c_row4_col14{
#             background-color:  #79cbc5;
#             color:  #000000;
#         }#T_7d20c_row3_col23{
#             background-color:  #c5e8c2;
#             color:  #000000;
#         }#T_7d20c_row3_col26{
#             background-color:  #2d8fbf;
#             color:  #000000;
#         }#T_7d20c_row3_col31{
#             background-color:  #bde5be;
#             color:  #000000;
#         }#T_7d20c_row3_col38{
#             background-color:  #6ec5c8;
#             color:  #000000;
#         }#T_7d20c_row4_col2{
#             background-color:  #49add0;
#             color:  #000000;
#         }#T_7d20c_row4_col3{
#             background-color:  #e8f6e2;
#             color:  #000000;
#         }#T_7d20c_row4_col7,#T_7d20c_row4_col15,#T_7d20c_row4_col31{
#             background-color:  #e7f6e2;
#             color:  #000000;
#         }#T_7d20c_row4_col10{
#             background-color:  #cdebc6;
#             color:  #000000;
#         }#T_7d20c_row4_col11,#T_7d20c_row4_col19,#T_7d20c_row4_col27,#T_7d20c_row4_col35,#T_7d20c_row4_col39{
#             background-color:  #e9f6e3;
#             color:  #000000;
#         }#T_7d20c_row4_col18{
#             background-color:  #b5e2bb;
#             color:  #000000;
#         }#T_7d20c_row4_col23{
#             background-color:  #e6f6e1;
#             color:  #000000;
#         }#T_7d20c_row4_col26{
#             background-color:  #ceecc8;
#             color:  #000000;
#         }#T_7d20c_row4_col30{
#             background-color:  #3c9fc8;
#             color:  #000000;
#         }#T_7d20c_row4_col34{
#             background-color:  #47abcf;
#             color:  #000000;
#         }#T_7d20c_row4_col38{
#             background-color:  #abdeb6;
#             color:  #000000;
#         }</style><table id="T_7d20c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="4">OPN1</th>        <th class="col_heading level0 col4" colspan="4">OPN2</th>        <th class="col_heading level0 col8" colspan="4">OPN3</th>        <th class="col_heading l

# %%
continents[['OPN1','OPN2','OPN3','OPN4','OPN5','OPN6','OPN7','OPN8','OPN9','OPN10','dateload','region']].groupby(['region']).agg(["sum"]).plot(kind="line",color =["orange","blue","green",'red','magenta','pink','skyblue','yellow','purple','black'])
plt.title("Sum : Open Personality traits across Countries (by Continent)", fontsize=20)
plt.ylabel("Open Personality",fontsize=10)
plt.xlabel(" ")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 4.Clustering
#
# Reference : https://www.kaggle.com/akdagmelih/five-personality-clusters-k-means

# %%
X=data.copy()
X.drop(X.columns[50:107], axis=1, inplace=True)
X.drop(X.columns[51:], axis=1, inplace=True)

# %% [markdown]
# ## 4.1 K-means
#
# [K-means](http://https//www.analyticsvidhya.com/blog/2019/08/comprehensive-guide-k-means-clustering/) is a centroid-based algorithm, or a distance-based algorithm, where we calculate the distances to assign a point to a cluster. In K-Means, each cluster is associated with a centroid.

# %%
# Creating K-means Cluster Model
from sklearn.cluster import KMeans

df_model = X.drop('country', axis=1)

#fit model
kmeans = KMeans(n_clusters=5)
k_fit = kmeans.fit(df_model)

# %%
# Predicting the Clusters
pd.options.display.max_columns = 10
predictions = k_fit.labels_
df_model['Clusters'] = predictions
df_model.head()
# Out:
#    EXT1  EXT2  EXT3  EXT4  EXT5  ...  OPN7  OPN8  OPN9  OPN10  Clusters
# 0   4.0   1.0   5.0   2.0   5.0  ...   5.0   3.0   4.0    5.0         2
# 1   3.0   5.0   3.0   4.0   3.0  ...   4.0   2.0   5.0    3.0         3
# 2   2.0   3.0   4.0   4.0   3.0  ...   5.0   3.0   4.0    4.0         3
# 3   2.0   2.0   2.0   3.0   4.0  ...   4.0   4.0   3.0    3.0         0
# 4   3.0   3.0   3.0   3.0   5.0  ...   5.0   3.0   5.0    5.0         2
#
# [5 rows x 51 columns]

# %%
# Summing up the different questions groups
col_list = list(df_model)
ext = col_list[0:10]
est = col_list[10:20]
agr = col_list[20:30]
csn = col_list[30:40]
opn = col_list[40:50]

data_sums = pd.DataFrame()
data_sums['extroversion'] = df_model[ext].sum(axis=1)/10
data_sums['neurotic'] = df_model[est].sum(axis=1)/10
data_sums['agreeable'] = df_model[agr].sum(axis=1)/10
data_sums['conscientious'] = df_model[csn].sum(axis=1)/10
data_sums['open'] = df_model[opn].sum(axis=1)/10
data_sums['clusters'] = predictions
data_sums.groupby('clusters').mean()
# Out:
#           extroversion  neurotic  agreeable  conscientious      open
# clusters
# 0             2.908987  2.526633   2.851263       2.914635  3.120629
# 1             2.966214  3.646822   3.149307       3.173552  3.246002
# 2             3.085542  2.422058   3.208824       3.106760  3.326828
# 3             3.051700  2.985974   3.187322       3.158968  3.243342
# 4             3.072316  3.424315   3.299975       3.211170  3.352560

# %% [markdown]
# ## 4.2 PCA
#
# [Principal Component Analysis (PCA)](https://rpubs.com/cyobero/pca-clustering#:~:text=Principal%20Component%20Analysis%20(PCA)%20is%20an%20unsupervised%20machine%20learning%20technique,Visualizing%20High%2DDimensional) is an unsupervised machine learning technique that attempts to derive a set of low-dimensional set of features from a much larger set while still preserving as much variance as possible.

# %%
# In order to visualize in 2D graph I will use PCA
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_fit = pca.fit_transform(df_model)

df_pca = pd.DataFrame(data=pca_fit, columns=['PCA1', 'PCA2'])
df_pca['Clusters'] = predictions
df_pca.head()
# Out:
#        PCA1      PCA2  Clusters
# 0 -5.416310 -0.443080         2
# 1  0.316312  2.306980         3
# 2 -0.586472  1.731914         3
# 3  1.494434  0.867790         0
# 4 -4.463153  2.662164         2

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=df_pca, x='PCA1', y='PCA2', hue='Clusters', palette='tab10', alpha=0.8)
plt.title('Personality Clusters after PCA');

# %% [markdown]
# ## 4.3 TSNE
#
# [t-Distributed Stochastic Neighbor Embedding (t-SNE)](https://www.datacamp.com/community/tutorials/introduction-t-sne) is a non-linear technique for dimensionality reduction that is particularly well suited for the visualization of high-dimensional datasets. It is extensively applied in image processing, NLP, genomic data and speech processing.

# %%
from sklearn.manifold import TSNE

Xtsne = TSNE(n_components=2).fit_transform(df_pca)
dftsne = pd.DataFrame(data=Xtsne , columns = ['x1','x2'])
dftsne['cluster'] = predictions
dftsne.head()
# Out:
#           x1         x2  cluster
# 0 -15.890965   4.540319        2
# 1  -4.104282 -18.559158        3
# 2 -11.795679   7.794142        3
# 3   8.230244  10.559387        0
# 4   0.773786  12.976888        2

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=dftsne,x='x1',y='x2',hue='cluster',legend="full", palette='tab10', alpha=0.8)
plt.title('Personality Clusters Visualized on TSNE 2D');

# %% [markdown]
# References :
# * [1] https://www.123test.com/big-five-personality-theory/
# * [2] https://openpsychometrics.org/tests/IPIP-BFFM/
# * [3] Goldberg, Lewis R. "The development of markers for the Big-Five factor structure." Psychological assessment 4.1 (1992): 26.
# * [4] https://www.kaggle.com/akdagmelih/five-personality-clusters-k-means
# * [5] http://https//www.analyticsvidhya.com/blog/2019/08/comprehensive-guide-k-means-clustering/
# * [6] https://www.datacamp.com/community/tutorials/introduction-t-sne
# * [7] Viz Ref: https://www.kaggle.com/dwin183287/kagglers-seen-by-continents
